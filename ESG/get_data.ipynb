# %%
#Get data from the SIX API
import pandas as pd

# Load the dataset
file_path = 'EUESGMANUFACTURER.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#    swissValorNumber          ISIN           ISIN_BC  \
# 0          28101647  CH0281016474  CH0281016474_393
# 1          28101647  CH0281016474  CH0281016474_393
# 2          28101647  CH0281016474  CH0281016474_393
# 3          28101647  CH0281016474  CH0281016474_393
# 4          28101647  CH0281016474  CH0281016474_393
#
#                          FISN  issuerSIXCompanyKey                   LEI  \
# 0  Von Fd PenInYd/Ut Cl-A CHF               693053  5493005ZZWAG5GH0G736
# 1  Von Fd PenInYd/Ut Cl-A CHF               693053  5493005ZZWAG5GH0G736
# 2  Von Fd PenInYd/Ut Cl-A CHF               693053  5493005ZZWAG5GH0G736
# 3  Von Fd PenInYd/Ut Cl-A CHF               693053  5493005ZZWAG5GH0G736
# 4  Von Fd PenInYd/Ut Cl-A CHF               693053  5493005ZZWAG5GH0G736
#
#   companyDomicile companyDomicileISO  \
# 0     Switzerland                 CH
# 1     Switzerland                 CH
# 2     Switzerland                 CH
# 3     Switzerland                 CH
# 4     Switzerland                 CH
#
#                              companyLongName  fundManagerSIXCompanyKey  ...  \
# 0  Vontobel Fund (CH) - Pension Invest Yield                  552303.0  ...
# 1  Vontobel Fund (CH) - Pension Invest Yield                  552303.0  ...
# 2  Vontobel Fund (CH) - Pension Invest Yield                  552303.0  ...
# 3  Vontobel Fund (CH) - Pension Invest Yield                  552303.0  ...
# 4  Vontobel Fund (CH) - Pension Invest Yield                  552303.0  ...
#
#   ESGValidFrom ESGDeliveryDate  \
# 0   2024-02-01      2024-02-02
# 1   2024-02-01      2024-02-02
# 2   2024-02-01      2024-02-02
# 3   2024-02-01      2024-02-02
# 4   2024-02-01      2024-02-02
#
#                                       ESGActivity         ESGClassification  \
# 0  Data Set, Manufacturer and Product information  EET Data Set Information
# 1  Data Set, Manufacturer and Product information  EET Data Set Information
# 2  Data Set, Manufacturer and Product information  EET Data Set Information
# 3  Data Set, Manufacturer and Product information  EET Data Set Information
# 4  Data Set, Manufacturer and Product information  EET Data Set Information
#
#                                        ESGFactor ESGFactorProviderId  \
# 0                              00010_EET_Version               00010
# 1  00060_EET_Data_Reporting_SFDR_Pre_Contractual               00060
# 2         00070_EET_Data_Reporting_SFDR_Periodic               00070
# 3     00080_EET_Data_Reporting_SFDR_Entity_Level               00080
# 4                 00090_EET_Data_Reporting_MiFID               00090
#
#   ESGFactorAmountLastYear ESGFactorAmountLastYearUnit  ESGClassSymbol  \
# 0                    1.11                         NaN             NaN
# 1                     NaN                         NaN     ESG3-2 : No
# 2                     NaN                         NaN     ESG3-2 : No
# 3                     NaN                         NaN     ESG3-2 : No
# 4                     NaN                         NaN     ESG3-2 : No
#
#   ESGFactorDate
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 22 columns]

# %%
# Reshape the data
reshaped_data = data.copy().pivot_table(index='ISIN', columns='ESGFactor', values='ESGFactorAmountLastYear', aggfunc='first')
reshaped_data_units = data.copy().pivot_table(index='ISIN', columns='ESGFactor', values='ESGFactorAmountLastYearUnit', aggfunc='first')

# Display the reshaped data's first few rows
display(reshaped_data.head())
reshaped_data_units.sort_index().head()

print(f'Are all ISIN unique: {len(reshaped_data.index.unique()) == reshaped_data.shape[0]}; Shape: {reshaped_data.shape}')
# Out:
# ESGFactor     00010_EET_Version  11011_Manufacturer_PRI_Notation_Percentage  \
# ISIN
# AT0000774484               1.11                                        0.93
# AT0000784756               1.11                                         NaN
# AT0000785340               1.11                                        0.76
# AT0000799804               1.11                                         NaN
# AT0000799820               1.11                                         NaN
#
# ESGFactor     20040_Financial_Instrument_SFDR_Product_Type  \
# ISIN
# AT0000774484                                           8.0
# AT0000784756                                           6.0
# AT0000785340                                           8.0
# AT0000799804                                           6.0
# AT0000799820                                           8.0
#
# ESGFactor     20050_Financial_Instrument_SFDR_Product_Type_Eligible  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                NaN
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     20070_Financial_Instrument_Percentage_Of_Minimum_SFDR_Art_8_Funds  \
# ISIN
# AT0000774484                                                0.0
# AT0000784756                                                0.0
# AT0000785340                                                1.0
# AT0000799804                                                0.0
# AT0000799820                                                0.0
#
# ESGFactor     20080_Financial_Instrument_Percentage_Of_Minimum_SFDR_Art_9_Funds  \
# ISIN
# AT0000774484                                                0.0
# AT0000784756                                                0.0
# AT0000785340                                                0.0
# AT0000799804                                                0.0
# AT0000799820                                                0.0
#
# ESGFactor     20180_Financial_Instrument_Products_Minimal_Proportion_Of_Sustainable_Investments_Art_8  \
# ISIN
# AT0000774484                                               0.51
# AT0000784756                                                NaN
# AT0000785340                                               0.51
# AT0000799804                                                NaN
# AT0000799820                                               0.51
#
# ESGFactor     20220_Financial_Instrument_Minimum_Sustainable_Investment_With_Environmental_Objective_Art_9  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                NaN
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     20250_Financial_Instrument_Minimum_Sustainable_Investment_Social_Objective_Art_9  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                NaN
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     20310_Financial_Instrument_Weight_Of_Eligible_Issuers  ...  \
# ISIN                                                                 ...
# AT0000774484                                           0.913207      ...
# AT0000784756                                                NaN      ...
# AT0000785340                                                NaN      ...
# AT0000799804                                                NaN      ...
# AT0000799820                                                NaN      ...
#
# ESGFactor     90160_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_Nuclear_ Incl_Sovereign_Bonds_Capex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90170_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_Nuclear_Excl_Sovereign_Bonds_Capex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90180_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_No_Fossil_Gas_and_Nuclear_ Incl_Sovereign_Bonds_Capex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90190_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_No_Fossil_Gas_and_Nuclear_Excl_Sovereign_Bonds_Capex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90200_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_Fossil_Gas_ Incl_Sovereign_Bonds_Opex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90210_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_Fossil_Gas_Excl_Sovereign_Bonds_Opex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90220_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_Nuclear_ Incl_Sovereign_Bonds_Opex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90230_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_Nuclear_Excl_Sovereign_Bonds_Opex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90240_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_No_Fossil_Gas_and_Nuclear_ Incl_Sovereign_Bonds_Opex  \
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# ESGFactor     90250_Financial_Instrument_Current_Percentage_Investments_Aligned_EU_Taxonomy_No_Fossil_Gas_and_Nuclear_Excl_Sovereign_Bonds_Opex
# ISIN
# AT0000774484                                                NaN
# AT0000784756                                                NaN
# AT0000785340                                                0.0
# AT0000799804                                                NaN
# AT0000799820                                                NaN
#
# [5 rows x 366 columns]
# Are all ISIN unique: True; Shape: (672, 366)

# %%
df=data.copy()
print(f'{len(df["ISIN"].unique())} companies in the dataset')
print(f'{len(reshaped_data["30020_GHG_Emissions_Scope_1_Value"].unique())-1} scope 1 entries')
print(f'{len(reshaped_data["30060_GHG_Emissions_Scope_2_Value"].unique())-1} scope 2 entries')
print(f'{len(reshaped_data["30100_GHG_Emissions_Scope_3_Value"].unique())-1} scope 3 entries')

#Get entries for which all 3 scope entries are available
scope1 = reshaped_data['30020_GHG_Emissions_Scope_1_Value']
scope2 = reshaped_data['30060_GHG_Emissions_Scope_2_Value']
scope3 = reshaped_data['30100_GHG_Emissions_Scope_3_Value']

#Join the scopes by ISIN and drop zeros, they are in tCO2e/M€ invested
scope = pd.concat([scope1,scope2,scope3], axis=1).dropna()
scope["total"] = scope.sum(axis=1)
scope["z-score"] = (scope["total"] - scope["total"].mean())/scope["total"].std(ddof=0)
scope.head()

display(scope)
scope.value_counts()
# Out:
# 672 companies in the dataset
# 214 scope 1 entries
# 214 scope 2 entries
# 202 scope 3 entries
#               30020_GHG_Emissions_Scope_1_Value  \
# ISIN
# AT0000774484                       26434.814652
# AT0000785340                         527.170000
# AT0000801071                        9352.620000
# AT0000801097                       18195.300000
# AT0000802491                       18973.101548
# ...                                         ...
# SE0013749397                        2809.213700
# SE0013749405                        2809.213700
# SE0017767692                          82.271400
# SE0017767700                           5.495700
# US9219361006                        5873.817112
#
#               30060_GHG_Emissions_Scope_2_Value  \
# ISIN
# AT0000774484                        9605.616494
# AT0000785340                         353.810000
# AT0000801071                        4374.410000
# AT0000801097                        6182.420000
# AT0000802491                        6701.565351
# ...                                         ...
# SE0013749397                        2822.111200
# SE0013749405                        2822.111200
# SE0017767692                         103.814600
# SE0017767700                           4.267100
# US9219361006                        1531.221370
#
#               30100_GHG_Emissions_Scope_3_Value          total   z-score
# ISIN
# AT0000774484                       23042.033805   59082.464951 -0.162804
# AT0000785340                       16319.050000   17200.030000 -0.171441
# AT0000801071                        8616.010000   22343.040000 -0.170380
# AT0000801097                       13807.930000   38185.650000 -0.167113
# AT0000802491                      162230.585505  187905.252404 -0.136236
# ...                                         ...            ...       ...
# SE0013749397                       38729.830200   44361.155100 -0.165840
# SE0013749405                       38729.830200   44361.155100 -0.165840
# SE0017767692                        6811.356000    6997.442000 -0.173545
# SE0017767700                         206.377100     216.139900 -0.174944
# US9219361006                       45409.058860   52814.097342 -0.164096
#
# [340 rows x 5 columns]
# 30020_GHG_Emissions_Scope_1_Value  30060_GHG_Emissions_Scope_2_Value  30100_GHG_Emissions_Scope_3_Value  total         z-score
# 0.000000e+00                       0.000000                           0.000000e+00                       0.000000e+00  -0.174988    20
# 1.155877e+02                       63.045557                          2.496831e+03                       2.675464e+03  -0.174436     7
# 1.286204e+03                       479.068044                         1.197589e+03                       2.962861e+03  -0.174377     6
# 1.562488e+04                       3569.940000                        7.975540e+03                       2.717036e+04  -0.169385     6
# 5.304333e+04                       10121.600000                       2.347883e+04                       8.664376e+04  -0.157120     6
#                                                                                                                                     ..
# 2.327060e+03                       554.490000                         1.031550e+03                       3.913100e+03  -0.174181     1
# 2.474040e+03                       1241.520000                        2.994235e+04                       3.365791e+04  -0.168047     1
# 2.494200e+03                       1031.080000                        1.122760e+03                       4.648040e+03  -0.174030     1
# 2.643310e+03                       514.030000                         7.658300e+02                       3.923170e+03  -0.174179     1
# 3.491930e+06                       383638.247600                      4.208924e+07                       4.596481e+07   9.304391     1
# Name: count, Length: 202, dtype: int64
